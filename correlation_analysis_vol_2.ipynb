# %%
#importing libraries
from dateutil.parser import parse 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
# reading in the data file
df = pd.read_csv('/Users/kratipatidar/Desktop/prof_nara/data/data_corr.csv')
df
# Out:
#             bg_dest  date_start  dev_count       bg_orig            POI
# 0       60730056002  2020-01-01          1  420490110012    Balboa Park
# 1       60730056002  2020-01-01          1  361031580014    Balboa Park
# 2       60730056002  2020-01-01          1  120010018131    Balboa Park
# 3       60730056002  2020-01-01          1  121270825071    Balboa Park
# 4       60730056002  2020-01-01          1  110010009012    Balboa Park
# ...             ...         ...        ...           ...            ...
# 242606  60730212021  2020-09-21          2   40270111042  Viejas Casino
# 242607  60730212021  2020-09-21          1   60650464022  Viejas Casino
# 242608  60730212021  2020-09-21          1   60250117001  Viejas Casino
# 242609  60730212021  2020-09-21          1   60250107001  Viejas Casino
# 242610  60730079101  2020-09-21          1  150030074001  Mission Beach
#
# [242611 rows x 5 columns]

# %%
# let's pivot this table

df_pt = pd.pivot_table(df, )

# %%
# reading in the income and age (combined) file

inc_age = pd.read_csv('/Users/kratipatidar/Desktop/prof_nara/data/inc_age.csv')
inc_age.head()
# Out:
#    Unnamed: 0     TractID                                           geometry  \
# 0           0  6073017034  POLYGON ((-117.101805 32.996934, -117.100896 3...
# 1           1  6073017014  POLYGON ((-117.071 33.013903, -117.070513 33.0...
# 2           2  6073017104  POLYGON ((-117.248387 33.045653, -117.248331 3...
# 3           3  6073018504  POLYGON ((-117.356179 33.189215, -117.356016 3...
# 4           4  6073007501  POLYGON ((-117.244607 32.748195, -117.244435 3...
#
#      income  percent_20_24  percent_25_34  percent_35_44  percent_45_54  \
# 0  118750.0            6.0           15.8           14.8           13.7
# 1   62052.0            0.0            2.6            2.6            2.8
# 2  126765.0            3.5            7.9           13.4           12.3
# 3   90263.0            5.5            9.0           16.3           12.9
# 4   69563.0            6.0           34.5           23.2           12.1
#
#    percent_55_59  percent_60_64  percent_65_74  percent_75_84  \
# ...

# %%
# we will add a orig_tract column in df for merging with the inc_age dataframe

df['orig_tract'] = df['bg_orig'].floordiv(10)
df
# Out:
#             bg_dest  date_start  dev_count       bg_orig            POI  \
# 0       60730056002  2020-01-01          1  420490110012    Balboa Park
# 1       60730056002  2020-01-01          1  361031580014    Balboa Park
# 2       60730056002  2020-01-01          1  120010018131    Balboa Park
# 3       60730056002  2020-01-01          1  121270825071    Balboa Park
# 4       60730056002  2020-01-01          1  110010009012    Balboa Park
# ...             ...         ...        ...           ...            ...
# 242606  60730212021  2020-09-21          2   40270111042  Viejas Casino
# 242607  60730212021  2020-09-21          1   60650464022  Viejas Casino
# 242608  60730212021  2020-09-21          1   60250117001  Viejas Casino
# 242609  60730212021  2020-09-21          1   60250107001  Viejas Casino
# 242610  60730079101  2020-09-21          1  150030074001  Mission Beach
#
#          orig_tract
# 0       42049011001
# 1       36103158001
# 2       12001001813
# ...

# %%
# now we merge the two dataframes

df_inc_age = pd.merge(df, inc_age,  how='inner', left_on=['orig_tract'], right_on = ['TractID'])
df_inc_age.head()
# Out:
#        bg_dest  date_start  dev_count      bg_orig          POI  orig_tract  \
# 0  60730056002  2020-01-01          1  60730046002  Balboa Park  6073004600
# 1  60730056002  2020-01-01          1  60730046001  Balboa Park  6073004600
# 2  60730056002  2020-01-02          1  60730046001  Balboa Park  6073004600
# 3  60730056002  2020-01-03          1  60730046001  Balboa Park  6073004600
# 4  60730056002  2020-01-04          1  60730046002  Balboa Park  6073004600
#
#    Unnamed: 0     TractID                                           geometry  \
# 0          61  6073004600  POLYGON ((-117.14759 32.717865, -117.14756 32....
# 1          61  6073004600  POLYGON ((-117.14759 32.717865, -117.14756 32....
# 2          61  6073004600  POLYGON ((-117.14759 32.717865, -117.14756 32....
# 3          61  6073004600  POLYGON ((-117.14759 32.717865, -117.14756 32....
# 4          61  6073004600  POLYGON ((-117.14759 32.717865, -117.14756 32....
#
# ...

# %%
# we segregate the above dataframe into 3 parts

jan_wk = df_inc_age[(df_inc_age['date_start'] >= '2020-01-01') & (df_inc_age['date_start'] <= '2020-01-08')]
jan_wk
# Out:
#             bg_dest  date_start  dev_count      bg_orig            POI  \
# 0       60730056002  2020-01-01          1  60730046002    Balboa Park
# 1       60730056002  2020-01-01          1  60730046001    Balboa Park
# 2       60730056002  2020-01-02          1  60730046001    Balboa Park
# 3       60730056002  2020-01-03          1  60730046001    Balboa Park
# 4       60730056002  2020-01-04          1  60730046002    Balboa Park
# ...             ...         ...        ...          ...            ...
# 161074  60730212021  2020-01-08          1  60730033011  Viejas Casino
# 161255  60730056002  2020-01-07          1  60730101041    Balboa Park
# 161256  60730056002  2020-01-08          1  60730101042    Balboa Park
# 161352  60730056002  2020-01-07          2  60730197013    Balboa Park
# 161422  60730056002  2020-01-08          1  60730083131    Balboa Park
#
#         orig_tract  Unnamed: 0     TractID  \
# 0       6073004600          61  6073004600
# ...

# %%
pre_ld
# Out:
#                   bg_dest  dev_count   bg_orig  orig_tract  Unnamed: 0  \
# bg_dest          1.000000   0.024757  0.196308    0.196308   -0.054829
# dev_count        0.024757   1.000000  0.006515    0.006515    0.018984
# bg_orig          0.196308   0.006515  1.000000    1.000000   -0.069554
# orig_tract       0.196308   0.006515  1.000000    1.000000   -0.069553
# Unnamed: 0      -0.054829   0.018984 -0.069554   -0.069553    1.000000
# TractID          0.196308   0.006515  1.000000    1.000000   -0.069553
# income          -0.063721   0.007408  0.244832    0.244833    0.076338
# percent_20_24   -0.016896  -0.005995 -0.129572   -0.129571    0.022651
# percent_25_34   -0.120271   0.051190 -0.443128   -0.443129    0.103528
# percent_35_44   -0.084359   0.011366 -0.228101   -0.228102    0.108799
# percent_45_54    0.005094  -0.066178  0.152146    0.152147   -0.036088
# percent_55_59    0.082254  -0.008891  0.304149    0.304149   -0.052578
# ...
